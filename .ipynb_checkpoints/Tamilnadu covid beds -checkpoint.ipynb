# %% [markdown]
# TN Gov publishes the list of covid beds in each district in this page. This effort is to improve search easier

# %%
import pandas as pd
from bs4 import BeautifulSoup
import json

# %%
covid_beds_url = "https://stopcorona.tn.gov.in/beds.php"

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
import urllib.request
page = urllib.request.urlopen(covid_beds_url)

# %%
soup = BeautifulSoup(page.read())

# %%
table = soup.find("table", {"id": "dtBasicExample"})
df = pd.read_html(str(table))[0]

# %%
df.head(1)
# Out:
#   S.NO  District   Institution COVID BEDS                  \
#   S.NO  District   Institution      Total Occupied Vacant
# 0    1  Ariyalur  A.S Hospital         30       29      1
#
#   OXYGEN SUPPORTED BEDS                 NON-OXYGEN SUPPORTED BEDS  ...         \
#                   Total Occupied Vacant                     Total  ... Vacant
# 0                     8        8      0                        12  ...      0
#
#   ICU BEDS                 VENTILATOR                         Last updated  \
#      Total Occupied Vacant      Total Occupied Vacant         Last updated
# 0       10        9      1          2        2      0  2021-05-12 09:36:55
#
#   Contact Number     Remarks
#   Contact Number     Remarks
# 0            0.0  12.05.2021
#
# [1 rows x 21 columns]

# %%
correct_cols = ["S.NO", "District", "Institution", "Last updated", "Contact Number","Remarks"]

new_cols = [f"{column[0]}_{column[1]}" if column[0]!=column[1] else column[0] for column in df.columns]

# %%
df.columns = new_cols

# %%
df['Last updated'] = pd.to_datetime(df['Last updated'])
df['Contact Number'] = df['Contact Number'].astype(str)
df['Remarks'] = df['Remarks'].astype(str)

# %%
df.head(2)
# Out:
#    S.NO  District      Institution  COVID BEDS_Total  COVID BEDS_Occupied  \
# 0     1  Ariyalur     A.S Hospital                30                   29
# 1     2  Ariyalur  Golden Hospital                31                   30
#
#    COVID BEDS_Vacant  OXYGEN SUPPORTED BEDS_Total  \
# 0                  1                            8
# 1                  1                           23
#
#    OXYGEN SUPPORTED BEDS_Occupied  OXYGEN SUPPORTED BEDS_Vacant  \
# 0                               8                             0
# 1                              23                             0
#
#    NON-OXYGEN SUPPORTED BEDS_Total  ...  NON-OXYGEN SUPPORTED BEDS_Vacant  \
# 0                               12  ...                                 0
# 1                                3  ...                                 1
#
#    ICU BEDS_Total  ICU BEDS_Occupied  ICU BEDS_Vacant  VENTILATOR_Total  \
# 0              10                  9                1                 2
# 1               5                  5                0                 5
#
#    VENTILATOR_Occupied  VENTILATOR_Vacant        Last updated Contact Number  \
# 0                    2                  0 2021-05-12 09:36:55            0.0
# 1                    5                  0 2021-05-12 10:10:19   9487576493.0
#
#               Remarks
# 0          12.05.2021
# 1  Report 12/05/2021.
#
# [2 rows x 21 columns]

# %%
geo_data = []
for district in df['District'].unique():
    geo_dict = {
        "latitude" : 0,
        "longitude" : 0,
        "district" : district
    }
    geo_data.append(geo_dict)

# %%
'''import json
with open('geo.json', 'w') as out:
    json.dump({"geo_data": geo_data}, indent=4, fp=out)'''
# Out:
# 'import json\nwith open(\'geo.json\', \'w\') as out:\n    json.dump({"geo_data": geo_data}, indent=4, fp=out)'

# %%
with open('geo_districts.json',"r") as f:
    data = json.loads(f.read())

# %%
df_geo = pd.DataFrame(data.get('geo_data'))
print(df_geo.shape)
df_geo.head()
# Out:
# (35, 3)
#     latitude  longitude      district
# 0  11.140059  79.078629      Ariyalur
# 1  12.693620  79.980499  Chengalpattu
# 2  13.082680  80.270721       Chennai
# 3  12.834174  79.703644  Kancheepuram
# 4  11.016844  76.955833    Coimbatore

# %%
df_district = df.groupby('District', as_index=False).sum()
print(df_district.shape)
# Out:
# (35, 17)

# %%
df_district.head()
# Out:
#        District   S.NO  COVID BEDS_Total  COVID BEDS_Occupied  \
# 0      Ariyalur    969               101                   90
# 1  Chengalpattu   4190               683                  651
# 2    Chengalpet    320                25                   25
# 3       Chennai  45093              9667                 8673
# 4    Coimbatore   7947              3595                 3377
#
#    COVID BEDS_Vacant  OXYGEN SUPPORTED BEDS_Total  \
# 0                 11                           53
# 1                 32                          450
# 2                  0                           17
# 3                994                         5239
# 4                218                         1861
#
#    OXYGEN SUPPORTED BEDS_Occupied  OXYGEN SUPPORTED BEDS_Vacant  \
# 0                              47                             6
# 1                             448                             2
# 2                              17                             0
# 3                            5186                            53
# 4                            1824                            37
#
#    NON-OXYGEN SUPPORTED BEDS_Total  NON-OXYGEN SUPPORTED BEDS_Occupied  \
# 0                               24                                  21
# 1                              150                                 121
# 2                                7                                   7
# 3                             3057                                2120
# 4                             1417                                1236
#
#    NON-OXYGEN SUPPORTED BEDS_Vacant  ICU BEDS_Total  ICU BEDS_Occupied  \
# 0                                 3              24                 22
# 1                                29              83                 82
# 2                                 0               1                  1
# 3                               937            1371               1367
# 4                               181             324                317
#
#    ICU BEDS_Vacant  VENTILATOR_Total  VENTILATOR_Occupied  VENTILATOR_Vacant
# 0                2                 9                    7                  2
# 1                1                44                   40                  4
# 2                0                 1                    1                  0
# 3                4               616                  602                 14
# 4                7               177                  177                  0

# %%
df_district = pd.merge(
    df_district,
    df_geo,
    how="inner",
    left_on="District",
    right_on="district"
)

# %%
df_district.head()
# Out:
#        District   S.NO  COVID BEDS_Total  COVID BEDS_Occupied  \
# 0      Ariyalur    969               101                   90
# 1  Chengalpattu   4190               683                  651
# 2    Chengalpet    320                25                   25
# 3       Chennai  45093              9667                 8673
# 4    Coimbatore   7947              3595                 3377
#
#    COVID BEDS_Vacant  OXYGEN SUPPORTED BEDS_Total  \
# 0                 11                           53
# 1                 32                          450
# 2                  0                           17
# 3                994                         5239
# 4                218                         1861
#
#    OXYGEN SUPPORTED BEDS_Occupied  OXYGEN SUPPORTED BEDS_Vacant  \
# 0                              47                             6
# 1                             448                             2
# 2                              17                             0
# 3                            5186                            53
# 4                            1824                            37
#
#    NON-OXYGEN SUPPORTED BEDS_Total  NON-OXYGEN SUPPORTED BEDS_Occupied  \
# 0                               24                                  21
# 1                              150                                 121
# 2                                7                                   7
# 3                             3057                                2120
# 4                             1417                                1236
#
#    NON-OXYGEN SUPPORTED BEDS_Vacant  ICU BEDS_Total  ICU BEDS_Occupied  \
# 0                                 3              24                 22
# 1                                29              83                 82
# 2                                 0               1                  1
# 3                               937            1371               1367
# 4                               181             324                317
#
#    ICU BEDS_Vacant  VENTILATOR_Total  VENTILATOR_Occupied  VENTILATOR_Vacant  \
# 0                2                 9                    7                  2
# 1                1                44                   40                  4
# 2                0                 1                    1                  0
# 3                4               616                  602                 14
# 4                7               177                  177                  0
#
#     latitude  longitude      district
# 0  11.140059  79.078629      Ariyalur
# 1  12.693620  79.980499  Chengalpattu
# 2  12.684089  79.983637    Chengalpet
# 3  13.082680  80.270721       Chennai
# 4  11.016844  76.955833    Coimbatore

# %%
# Save all files
df.to_csv("tn_covid_beds.csv")
df_district.to_csv("tn_covid_district_beds.csv")

# %%
hosp_data = df[df['District'] == "Thanjavur"]

# %%
hosp_data.columns
# Out:
# Index(['S.NO', 'District', 'Institution', 'COVID BEDS_Total',
#        'COVID BEDS_Occupied', 'COVID BEDS_Vacant',
#        'OXYGEN SUPPORTED BEDS_Total', 'OXYGEN SUPPORTED BEDS_Occupied',
#        'OXYGEN SUPPORTED BEDS_Vacant', 'NON-OXYGEN SUPPORTED BEDS_Total',
#        'NON-OXYGEN SUPPORTED BEDS_Occupied',
#        'NON-OXYGEN SUPPORTED BEDS_Vacant', 'ICU BEDS_Total',
#        'ICU BEDS_Occupied', 'ICU BEDS_Vacant', 'VENTILATOR_Total',
#        'VENTILATOR_Occupied', 'VENTILATOR_Vacant', 'Last updated',
#        'Contact Number', 'Remarks'],
#       dtype='object')

# %%
show_cols = ["Institution", "Contact Number","Last updated","COVID BEDS_Vacant", "ICU BEDS_Vacant", "VENTILATOR_Vacant", 
             "OXYGEN SUPPORTED BEDS_Vacant", "NON-OXYGEN SUPPORTED BEDS_Vacant", "COVID BEDS_Total","ICU BEDS_Total","VENTILATOR_Total",
            "OXYGEN SUPPORTED BEDS_Total", "NON-OXYGEN SUPPORTED BEDS_Total"]

# %%
hosp_data = hosp_data[show_cols]
hosp_data = hosp_data.sort_values(by=['Last updated','COVID BEDS_Vacant'], ascending=False)

# %%
hosp_data
# Out:
#                                      Institution Contact Number  \
